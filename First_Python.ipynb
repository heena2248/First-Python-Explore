# %%
import numpy as np

# %%
import pandas as pd

# %%
data =pd.read_csv('E:/Heena/python/graduate-admissions/Admission_Predict.csv')

# %%
data.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0           1        337          118                  4  4.5   4.5  9.65
# 1           2        324          107                  4  4.0   4.5  8.87
# 2           3        316          104                  3  3.0   3.5  8.00
# 3           4        322          110                  3  3.5   2.5  8.67
# 4           5        314          103                  2  2.0   3.0  8.21
#
#    Research  Chance of Admit
# 0         1              0.92
# 1         1              0.76
# 2         1              0.72
# 3         1              0.80
# 4         0              0.65

# %%
print(data['SOP'])
# Out:
# 0      4.5
# 1      4.0
# 2      3.0
# 3      3.5
# 4      2.0
# 5      4.5
# 6      3.0
# 7      3.0
# 8      2.0
# 9      3.5
# 10     3.5
# 11     4.0
# 12     4.0
# 13     4.0
# 14     3.5
# 15     3.5
# 16     4.0
# 17     4.0
# 18     4.0
# 19     3.5
# 20     3.0
# 21     3.0
# 22     5.0
# 23     5.0
# 24     4.0
# 25     4.5
# 26     4.5
# 27     1.5
# 28     2.0
# 29     1.5
#       ...
# 370    2.5
# 371    3.5
# 372    4.5
# 373    3.0
# 374    2.0
# 375    2.0
# 376    2.5
# 377    1.5
# 378    2.0
# 379    2.5
# 380    3.5
# 381    3.0
# 382    4.5
# 383    3.0
# 384    5.0
# 385    5.0
# 386    2.5
# 387    2.0
# 388    1.5
# 389    3.5
# 390    2.0
# 391    2.0
# 392    4.0
# 393    3.0
# 394    4.5
# 395    3.5
# 396    3.0
# 397    5.0
# 398    3.5
# 399    5.0
# Name: SOP, Length: 400, dtype: float64

# %%
data[0:100]
# Out:
#     Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0            1        337          118                  4  4.5   4.5  9.65
# 1            2        324          107                  4  4.0   4.5  8.87
# 2            3        316          104                  3  3.0   3.5  8.00
# 3            4        322          110                  3  3.5   2.5  8.67
# 4            5        314          103                  2  2.0   3.0  8.21
# 5            6        330          115                  5  4.5   3.0  9.34
# 6            7        321          109                  3  3.0   4.0  8.20
# 7            8        308          101                  2  3.0   4.0  7.90
# 8            9        302          102                  1  2.0   1.5  8.00
# 9           10        323          108                  3  3.5   3.0  8.60
# 10          11        325          106                  3  3.5   4.0  8.40
# ...

# %%
print(data.axes)
# Out:
# [RangeIndex(start=0, stop=400, step=1), Index(['Serial No.', 'GRE Score', 'TOEFL Score', 'University Rating', 'SOP',
#        'LOR ', 'CGPA', 'Research', 'Chance of Admit '],
#       dtype='object')]

# %%
print(data.shape)
# Out:
# (400, 9)

# %%
print(data.sum())
# Out:
# Serial No.            80200.00
# GRE Score            126723.00
# TOEFL Score           42964.00
# University Rating      1235.00
# SOP                    1360.00
# LOR                    1381.00
# CGPA                   3439.57
# Research                219.00
# Chance of Admit         289.74
# dtype: float64

# %%
print(data.describe())
# Out:
#        Serial No.   GRE Score  TOEFL Score  University Rating         SOP  \
# count  400.000000  400.000000   400.000000         400.000000  400.000000
# mean   200.500000  316.807500   107.410000           3.087500    3.400000
# std    115.614301   11.473646     6.069514           1.143728    1.006869
# min      1.000000  290.000000    92.000000           1.000000    1.000000
# 25%    100.750000  308.000000   103.000000           2.000000    2.500000
# 50%    200.500000  317.000000   107.000000           3.000000    3.500000
# 75%    300.250000  325.000000   112.000000           4.000000    4.000000
# max    400.000000  340.000000   120.000000           5.000000    5.000000
#
#              LOR         CGPA    Research  Chance of Admit
# count  400.000000  400.000000  400.000000        400.000000
# mean     3.452500    8.598925    0.547500          0.724350
# std      0.898478    0.596317    0.498362          0.142609
# min      1.000000    6.800000    0.000000          0.340000
# ...

# %%
print(data.head())
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating    SOP   LOR   \
# 0       800.0    30800.0      10100.0              200.0  300.0  400.0
# 1         2.0      324.0        107.0                4.0    4.0    4.5
# 2         3.0      316.0        104.0                3.0    3.0    3.5
# 3         4.0      322.0        110.0                3.0    3.5    2.5
# 4         5.0      314.0        103.0                2.0    2.0    3.0
#
#      CGPA  Research  Chance of Admit
# 0  790.00       0.0             68.00
# 1    8.87       1.0              0.76
# 2    8.00       1.0              0.72
# 3    8.67       1.0              0.80
# 4    8.21       0.0              0.65

# %%
data
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0             1        337          118                  4  4.5   4.5  9.65
# 1             2        324          107                  4  4.0   4.5  8.87
# 2             3        316          104                  3  3.0   3.5  8.00
# 3             4        322          110                  3  3.5   2.5  8.67
# 4             5        314          103                  2  2.0   3.0  8.21
# 5             6        330          115                  5  4.5   3.0  9.34
# 6             7        321          109                  3  3.0   4.0  8.20
# 7             8        308          101                  2  3.0   4.0  7.90
# 8             9        302          102                  1  2.0   1.5  8.00
# 9            10        323          108                  3  3.5   3.0  8.60
# 10           11        325          106                  3  3.5   4.0  8.40
# ...

# %%
print(data.apply(np.mean,axis=1))
# Out:
# 0      53.396667
# 1      50.681111
# 2      49.135556
# 3      50.607778
# 4      48.651111
# 5      52.748889
# 6      50.772222
# 7      48.286667
# 8      47.333333
# 9      51.061111
# 10     51.380000
# 11     52.593333
# 12     52.931111
# 13     49.957778
# 14     49.812222
# 15     50.315556
# 16     51.151111
# 17     51.405556
# 18     51.825556
# 19     49.291111
# 20     50.837778
# 21     53.233333
# 22     54.826667
# 23     55.905556
# 24     56.030000
# 25     56.837778
# 26     53.395556
# 27     48.771111
# 28     47.740000
# 29     50.260000
#          ...
# 370    88.884444
# 371    91.845556
# 372    94.674444
# 373    91.481111
# 374    89.948889
# 375    88.393333
# 376    87.141111
# 377    86.725556
# 378    88.190000
# 379    89.626667
# 380    92.013333
# 381    91.766667
# 382    93.385556
# 383    89.153333
# 384    95.966667
# 385    96.086667
# 386    89.602222
# 387    90.681111
# 388    88.421111
# 389    93.188889
# 390    91.375556
# ...

# %%
print(data.apply(lambda x:x.max()-x.min(),axis=1))
# Out:
# 0      336.08
# 1      323.24
# 2      315.28
# 3      321.20
# 4      314.00
# 5      329.10
# 6      320.25
# 7      308.00
# 8      302.00
# 9      323.00
# 10     324.48
# 11     326.16
# 12     327.22
# 13     306.38
# 14     310.39
# 15     314.00
# 16     317.00
# 17     318.35
# 18     318.00
# 19     303.00
# 20     311.36
# 21     325.00
# 22     327.06
# 23     333.05
# 24     335.03
# 25     339.06
# 26     322.00
# 27     297.56
# 28     295.00
# 29     310.00
#         ...
# 370    371.00
# 371    371.11
# 372    372.05
# 373    373.21
# 374    375.00
# 375    376.00
# 376    377.00
# 377    378.00
# 378    379.00
# 379    379.29
# 380    380.22
# 381    381.27
# 382    382.18
# 383    384.00
# 384    384.04
# 385    385.04
# 386    387.00
# 387    388.00
# 388    389.00
# 389    389.24
# 390    391.00
# 391    392.00
# 392    392.16
# 393    394.00
# 394    394.11
# 395    395.18
# 396    396.16
# 397    397.09
# 398    399.00
# 399    399.05
# ...

# %%
data
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0             1        337          118                  4  4.5   4.5  9.65
# 1             2        324          107                  4  4.0   4.5  8.87
# 2             3        316          104                  3  3.0   3.5  8.00
# 3             4        322          110                  3  3.5   2.5  8.67
# 4             5        314          103                  2  2.0   3.0  8.21
# 5             6        330          115                  5  4.5   3.0  9.34
# 6             7        321          109                  3  3.0   4.0  8.20
# 7             8        308          101                  2  3.0   4.0  7.90
# 8             9        302          102                  1  2.0   1.5  8.00
# 9            10        323          108                  3  3.5   3.0  8.60
# 10           11        325          106                  3  3.5   4.0  8.40
# ...

# %%
data['SOP']=data['SOP']*100

# %%
data
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating        SOP   LOR   \
# 0           1.0      337.0        118.0                4.0    45000.0    4.5
# 1           2.0      324.0        107.0                4.0    40000.0    4.5
# 2           3.0      316.0        104.0                3.0    30000.0    3.5
# 3           4.0      322.0        110.0                3.0    35000.0    2.5
# 4           5.0      314.0        103.0                2.0    20000.0    3.0
# 5           6.0      330.0        115.0                5.0    45000.0    3.0
# 6           7.0      321.0        109.0                3.0    30000.0    4.0
# 7         800.0    30800.0      10100.0              200.0  3000000.0  400.0
# 8           9.0      302.0        102.0                1.0    20000.0    1.5
# 9          10.0      323.0        108.0                3.0    35000.0    3.0
# 10         11.0      325.0        106.0                3.0    35000.0    4.0
# ...

# %%
data.apply(np.mean,axis=1)
# Out:
# 0      53.396667
# 1      50.681111
# 2      49.135556
# 3      50.607778
# 4      48.651111
# 5      52.748889
# 6      50.772222
# 7      48.286667
# 8      47.333333
# 9      51.061111
# 10     51.380000
# 11     52.593333
# 12     52.931111
# 13     49.957778
# 14     49.812222
# 15     50.315556
# 16     51.151111
# 17     51.405556
# 18     51.825556
# 19     49.291111
# 20     50.837778
# 21     53.233333
# 22     54.826667
# 23     55.905556
# 24     56.030000
# 25     56.837778
# 26     53.395556
# 27     48.771111
# 28     47.740000
# 29     50.260000
#          ...
# 370    88.884444
# 371    91.845556
# 372    94.674444
# 373    91.481111
# 374    89.948889
# 375    88.393333
# 376    87.141111
# 377    86.725556
# 378    88.190000
# 379    89.626667
# 380    92.013333
# 381    91.766667
# 382    93.385556
# 383    89.153333
# 384    95.966667
# 385    96.086667
# 386    89.602222
# 387    90.681111
# 388    88.421111
# 389    93.188889
# 390    91.375556
# ...

# %%
data
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0             1        337          118                  4  4.5   4.5  9.65
# 1             2        324          107                  4  4.0   4.5  8.87
# 2             3        316          104                  3  3.0   3.5  8.00
# 3             4        322          110                  3  3.5   2.5  8.67
# 4             5        314          103                  2  2.0   3.0  8.21
# 5             6        330          115                  5  4.5   3.0  9.34
# 6             7        321          109                  3  3.0   4.0  8.20
# 7             8        308          101                  2  3.0   4.0  7.90
# 8             9        302          102                  1  2.0   1.5  8.00
# 9            10        323          108                  3  3.5   3.0  8.60
# 10           11        325          106                  3  3.5   4.0  8.40
# ...

# %%
print(data.sort_values(by='SOP',  ascending=False))
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 399         400        333          117                  4  5.0   4.0  9.66
# 151         152        332          116                  5  5.0   5.0  9.28
# 234         235        330          113                  5  5.0   4.0  9.31
# 215         216        330          116                  5  5.0   4.5  9.36
# 35           36        320          110                  5  5.0   5.0  9.20
# 213         214        333          119                  5  5.0   4.5  9.78
# 212         213        338          120                  4  5.0   5.0  9.66
# 211         212        328          110                  4  5.0   4.0  9.14
# 81           82        340          120                  4  5.0   5.0  9.50
# 45           46        322          110                  5  5.0   4.0  9.10
# 189         190        324          112                  5  5.0   5.0  9.08
# ...

# %%
data['GRE Score'].value_counts()[:20]
# Out:
# 324    19
# 312    19
# 316    14
# 322    14
# 314    14
# 321    13
# 325    13
# 311    12
# 317    12
# 320    12
# 327    12
# 308    11
# 326    11
# 313    11
# 323    10
# 315    10
# 329     9
# 300     9
# 319     9
# 318     9
# Name: GRE Score, dtype: int64

# %%
data['GRE Score'].value_counts()[:20].plot(kind='barh')

# %%
res=data[data['Research']==1]

# %%
res

# %%
res['GRE Score'].value_counts().to_frame().reset_index().sort_values('index', ascending=False)
# Out:
#     index  GRE Score
# 8     340          8
# 33    339          2
# 22    338          4
# 37    337          1
# 17    336          5
# 21    335          4
# 13    334          7
# 25    333          4
# 20    332          5
# 11    331          8
# 16    330          6
# 6     329          9
# 15    328          6
# 5     327         10
# 4     326         10
# 3     325         10
# 0     324         17
# 9     323          8
# 2     322         11
# 1     321         11
# 10    320          8
# 19    319          5
# 23    318          4
# 24    317          4
# 14    316          7
# 31    315          2
# 28    314          3
# 29    313          3
# 7     312          9
# 12    311          7
# 30    310          2
# 26    308          3
# 32    307          2
# 34    306          1
# 35    304          1
# 36    303          1
# 18    301          5
# 27    300          3
# 38    298          1
# 39    296          1
# 40    293          1

# %%
list(data.columns)
# Out:
# ['Serial No.',
#  'GRE Score',
#  'TOEFL Score',
#  'University Rating',
#  'SOP',
#  'LOR ',
#  'CGPA',
#  'Research',
#  'Chance of Admit ']

# %%
# Out:
# 324    17
# 321    11
# 322    11
# 325    10
# 326    10
# 327    10
# 329     9
# 312     9
# 340     8
# 323     8
# 320     8
# 331     8
# 311     7
# 334     7
# 316     7
# 328     6
# 330     6
# 336     5
# 301     5
# 319     5
# 332     5
# 335     4
# 338     4
# 318     4
# 317     4
# 333     4
# 308     3
# 300     3
# 314     3
# 313     3
# 310     2
# 315     2
# 307     2
# 339     2
# 306     1
# 304     1
# 303     1
# 337     1
# 298     1
# 296     1
# 293     1
# dtype: int64

# %%
df.sort_values(['GRE'],ascending=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-141-a2586171aea7> in <module>()
# ----> 1 df.sort_values(['GRE'],ascending=False)
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in sort_values(self, axis, ascending, inplace, kind, na_position)
#    2442         """
#    2443         inplace = validate_bool_kwarg(inplace, 'inplace')
# -> 2444         axis = self._get_axis_number(axis)
#    2445
#    2446         # GH 5856/5853
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_axis_number(self, axis)
#     362
#     363     def _get_axis_number(self, axis):
# --> 364         axis = self._AXIS_ALIASES.get(axis, axis)
#     365         if is_integer(axis):
#     366             if axis in self._AXIS_NAMES:
#
# TypeError: unhashable type: 'list'

# %%
type(df)
# Out:
# pandas.core.series.Series

# %%
data
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0             1        337          118                  4  4.5   4.5  9.65
# 1             2        324          107                  4  4.0   4.5  8.87
# 2             3        316          104                  3  3.0   3.5  8.00
# 3             4        322          110                  3  3.5   2.5  8.67
# 4             5        314          103                  2  2.0   3.0  8.21
# 5             6        330          115                  5  4.5   3.0  9.34
# 6             7        321          109                  3  3.0   4.0  8.20
# 7             8        308          101                  2  3.0   4.0  7.90
# 8             9        302          102                  1  2.0   1.5  8.00
# 9            10        323          108                  3  3.5   3.0  8.60
# 10           11        325          106                  3  3.5   4.0  8.40
# ...

# %%
good=[4,5]
def univ_rate(univ_rating):
    if univ_rating in good:
        return 'good'
    else:
        return 'ok'

# %%
data['univ']=data['University Rating'].apply(univ_rate)

# %%
data[['univ','University Rating']].head()
# Out:
#    univ  University Rating
# 0  good                  4
# 1  good                  4
# 2    ok                  3
# 3    ok                  3
# 4    ok                  2

# %%
data['univ'].value_counts().plot(kind='bar')

# %%
non_res=data[data['Research'] != 0 ]
non_res
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0             1        337          118                  4  4.5   4.5  9.65
# 1             2        324          107                  4  4.0   4.5  8.87
# 2             3        316          104                  3  3.0   3.5  8.00
# 3             4        322          110                  3  3.5   2.5  8.67
# 5             6        330          115                  5  4.5   3.0  9.34
# 6             7        321          109                  3  3.0   4.0  8.20
# 10           11        325          106                  3  3.5   4.0  8.40
# 11           12        327          111                  4  4.0   4.5  9.00
# 12           13        328          112                  4  4.0   4.5  9.10
# 13           14        307          109                  3  4.0   3.0  8.00
# 14           15        311          104                  3  3.5   2.0  8.20
# ...

# %%
non_res['univ'].value_counts().plot(kind='bar')

# %%
data
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0             1        337          118                  4  4.5   4.5  9.65
# 1             2        324          107                  4  4.0   4.5  8.87
# 2             3        316          104                  3  3.0   3.5  8.00
# 3             4        322          110                  3  3.5   2.5  8.67
# 4             5        314          103                  2  2.0   3.0  8.21
# 5             6        330          115                  5  4.5   3.0  9.34
# 6             7        321          109                  3  3.0   4.0  8.20
# 7             8        308          101                  2  3.0   4.0  7.90
# 8             9        302          102                  1  2.0   1.5  8.00
# 9            10        323          108                  3  3.5   3.0  8.60
# 10           11        325          106                  3  3.5   4.0  8.40
# ...

# %%
g=data.groupby(['Research','GRE Score'])

# %%
g.size()
# Out:
# Research  GRE Score
# 0         290           2
#           294           2
#           295           4
#           296           4
#           297           4
#           298           6
#           299           8
#           300           6
#           301           3
#           302           5
#           303           4
#           304           7
#           305           8
#           306           5
#           307           6
#           308           8
#           309           6
#           310           6
#           311           5
#           312          10
#           313           8
#           314          11
#           315           8
#           316           7
#           317           8
#           318           5
#           319           4
#           320           4
#           321           2
#           322           3
#                        ..
# 1         311           7
#           312           9
#           313           3
# ...

# %%
g1=g.size().unstack()
g1
# Out:
# GRE Score  290  293  294  295  296  297  298  299  300  301 ...   331  332  \
# Research                                                    ...
# 0          2.0  NaN  2.0  4.0  4.0  4.0  6.0  8.0  6.0  3.0 ...   NaN  1.0
# 1          NaN  1.0  NaN  NaN  1.0  NaN  1.0  NaN  3.0  5.0 ...   8.0  5.0
#
# GRE Score  333  334  335  336  337  338  339  340
# Research
# 0          NaN  NaN  NaN  NaN  NaN  NaN  1.0  NaN
# 1          4.0  7.0  4.0  5.0  1.0  4.0  2.0  8.0
#
# [2 rows x 49 columns]

# %%
g1.plot(kind='bar')
